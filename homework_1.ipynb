# %% [markdown]
# **Задание 1**. Даны 2 строки: *long_phrase* и *short_phrase*.
# Напишите код, который проверяет действительно ли длинная фраза *long_phrase* длиннее короткой *short_phrase*. И выводит *True* или *False* в зависимости от результата сравнения.

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'

# %%
len(long_phrase) > len(short_phrase)
# Out:
# True

# %% [markdown]
# **Задание 2**. Дано значение объема файла в байтах. Напишите перевод этого значения в мегабайты в формате: "*Объем файла равен 213.68Mb*"

# %%
file_size = int(input('Введите размер файла в байтах '))
mb = file_size / 1024**2
print('Объём файла равен: ', '%.2f' % mb, 'Mb', sep='')
# Out:
# Введите размер файла в байтах 1234567
# Объём файла равен: 1.18Mb

# %%
## для себя вариант...

file_size = int(input('Введите размер файла в байтах '))
mb = file_size / 1024**2
gb = file_size / 1024**3
if file_size < 1024**3:
    print('Объём файла равен: ', '%.2f' % mb, 'Mb', sep='')
else:
    print('Объём файла равен: ', '%.2f' % gb, 'Gb', sep='')
# Out:
# Введите размер файла в байтах 5454554545
# Объём файла равен: 5.08Gb

# %% [markdown]
# **Задание 3**. Разработать приложение для определения знака зодиака по дате рождения. Пример:
#
# Введите месяц: март
#
# Введите число: 6
#
# Вывод:
# Рыбы

# %%
month = str(input('Введите месяц: '))
day = int(input('Введите число: '))
if (month.lower() == 'март' and 31 >= day >= 21) or (month.lower() == 'апрель' and day <= 20):
    print('Ваш знак зодиака: Овен')
elif (month.lower() == 'апрель' and 30 >= day >= 21) or (month.lower() == 'май' and day <= 20):
    print('Ваш знак зодиака: Телец')
elif (month.lower() == 'май' and 31 >= day >= 21) or (month.lower() == 'июнь' and day <= 21):
    print('Ваш знак зодиака: Близнецы')
elif (month.lower() == 'июнь' and 30 >= day >= 22) or (month.lower() == 'июль' and day <= 22):
    print('Ваш знак зодиака: Рак')
elif (month.lower() == 'июль' and 31 >= day >= 23) or (month.lower() == 'август' and day <= 23):
    print('Ваш знак зодиака: Лев')
elif (month.lower() == 'август' and 31 >= day >= 24) or (month.lower() == 'сентябрь' and day <= 23):
    print('Ваш знак зодиака: Дева')
elif (month.lower() == 'сентябрь' and 30 >= day >= 24) or (month.lower() == 'октябрь' and day <= 23):
    print('Ваш знак зодиака: Весы')
elif (month.lower() == 'октябрь' and 31 >= day >= 24) or (month.lower() == 'ноябрь' and day <= 23):
    print('Ваш знак зодиака: Скорпион')
elif (month.lower() == 'ноября' and 30 >= day >= 24) or (month.lower() == 'декабрь' and day <= 21):
    print('Ваш знак зодиака: Стрелец')
elif (month.lower() == 'декабря' and 31 >= day >= 22) or (month.lower() == 'январь' and day <= 20):
    print('Ваш знак зодиака: Козерог')
elif (month.lower() == 'январь' and 31 >= day >= 21) or (month.lower() == 'февраль' and day <= 20):
    print('Ваш знак зодиака: Водолей')
elif (month.lower() == 'февраль' and 29 >= day >= 21) or (month.lower() == 'март' and day <= 20):
    print('Ваш знак зодиака: Рыбы')
else:
    print('Вы допустиль ошибку при вводе месяца или числа, поробуйте ещё раз.')
# Out:
# Введите месяц: Март
# Введите число: 6
# Ваш знак зодиака: Рыбы

# %% [markdown]
# **Задание 4**. Нужно разработать приложение для финансового планирования.
# Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию.
# Пользователь вводит:
# - заработанную плату в месяц.
# - сколько процентов от ЗП уходит на ипотеку.
# - сколько процентов от ЗП уходит "на жизнь".
# - сколько раз приходит премия в год.
#
# Остальная часть заработанной платы откладывается на пенсию.
#
# Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.
#
# Программа должна учитывать сколько премий было в год.
#
# Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.
#
# Пример:
#
# Введите заработанную плату в месяц: 100000
#
# Введите сколько процентов уходит на ипотеку: 30
#
# Введите сколько процентов уходит на жизнь: 50
#
# Введите количество премий за год: 2
#
# Вывод:
# На ипотеку было потрачено: 360000 рублей
# Было накоплено: 340000 рублей

# %%
zp = int(input('Введите заработную плату в месяц: '))
credit = int(input('Введите сколько процентов уходит на ипотеку: '))
life = int(input('Введите сколько процентов уходит на жизнь: '))
bonus = int(input('Введите Введите количество премий за год: '))

print('На ипотеку было потрачено:', zp*12//100*credit, 'руб.')

print('Было отложено на пенсию:  ', (zp*12+zp*bonus//2)-(zp*12//100*credit)-(zp*12//100*life) , 'руб.')

print('Было отложено на отпуск:  ', zp*bonus//2, 'руб.')
# Out:
# Введите заработную плату в месяц: 100000
# Введите сколько процентов уходит на ипотеку: 30
# Введите сколько процентов уходит на жизнь: 50
# Введите Введите количество премий за год: 2
# На ипотеку было потрачено: 360000 руб.
# Было отложено на пенсию:   340000 руб.
# Было отложено на отпуск:   100000 руб.

# %% [markdown]
# ## Дополнительное задание

# %% [markdown]
# ### Задание 3
# Дано слово из латинских букв. Напишите скрипт, который выводит на экран букву из середины слова (если число букв нечетное). Если букв четное число, то на экран выводятся две буквы из середины.
#
# Для ‘test’ - 'es’
# Для ‘testing’ - ‘t’

# %%
# я так понял мы это не проходили поэтому как смог... по гуманитарски =)))))
# первые два доп задания и вовсе заставили меня почувствовать технологическую сингулярность =))))))
# попробую решить их спустя несколько лекций...

word = str(input('Введите слово: '))
lword = len(word)
x = lword//2-1
y = x+2
z = x+1
if  lword % 2 == 0:
   print(word[x:y])
else:
   print(word[z])
# Out:
# Введите слово: test
# es
